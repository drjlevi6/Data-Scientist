# %%
# %matplotlib inline

import pandas as pd
from pandas import DataFrame
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn import metrics

# %%
df = pd.read_excel("xpm_dataset_copy.xlsx") 
df
# Out:
#                              File  Pxl-0  Pxl-1  Pxl-2  Pxl-3  Pxl-4  Pxl-5  \
# 0       xpm_single-letter-0-0.xpm    116    116    116    116    116    116
# 1     xpm_single-letter-0-100.xpm    116      0      0      0      0      0
# 2     xpm_single-letter-0-200.xpm    116    116    116    116    116    116
# 3     xpm_single-letter-0-300.xpm    116    116    116    116    116    116
# 4     xpm_single-letter-0-400.xpm    116    116    116    116    116    116
# ..                            ...    ...    ...    ...    ...    ...    ...
# 59  xpm_single-letter-700-300.xpm    116    116    116    116    116    116
# 60  xpm_single-letter-700-400.xpm    116    116    116    116    116    116
# 61  xpm_single-letter-700-500.xpm    116    116    116    116    116    116
# 62  xpm_single-letter-700-600.xpm    116    116    116    116    116    116
# 63  xpm_single-letter-700-700.xpm    116    116    116    116    116    116
#
# ...

# %%
# Extract pixel data
# df.shape # (64, 10002)
df_data_column_list = list(range(1,df.shape[1]-1))
df_pixel_data = df.iloc[:, df_data_column_list]
df_pixel_data
# Out:
#     Pxl-0  Pxl-1  Pxl-2  Pxl-3  Pxl-4  Pxl-5  Pxl-6  Pxl-7  Pxl-8  Pxl-9  ...  \
# 0     116    116    116    116    116    116    116    116    116    116  ...
# 1     116      0      0      0      0      0      0      0      0      0  ...
# 2     116    116    116    116    116    116    116    116    116    116  ...
# 3     116    116    116    116    116    116    116    116    116    116  ...
# 4     116    116    116    116    116    116    116    116    116    116  ...
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...  ...
# 59    116    116    116    116    116    116    116    116    116    116  ...
# 60    116    116    116    116    116    116    116    116    116    116  ...
# 61    116    116    116    116    116    116    116    116    116    116  ...
# 62    116    116    116    116    116    116    116    116    116    116  ...
# 63    116    116    116    116    116    116    116    116    116    116  ...
#
# ...

# %%
X = df_pixel_data.values
y = df.loc[:, 'Letter'].values
X, y
# Out:
# (array([[116, 116, 116, ..., 255, 255, 255],
#         [116,   0,   0, ...,   0,   0,   0],
#         [116, 116, 116, ..., 255, 255, 255],
#         ...,
#         [116, 116, 116, ..., 255, 255, 255],
#         [116, 116, 116, ..., 255, 255, 255],
#         [116, 116, 116, ..., 255, 255, 255]]),
#  array(['a', 'b', 'c', 'c', 'd', 'd', 'a', 'b', 'a', 'b', 'c', 'c', 'd',
#         'd', 'a', 'b', 'a', 'b', 'c', 'c', 'd', 'd', 'a', 'b', 'a', 'b',
#         'c', 'c', 'd', 'd', 'a', 'b', 'a', 'b', 'c', 'c', 'd', 'd', 'a',
#         'b', 'a', 'b', 'c', 'c', 'd', 'd', 'a', 'b', 'a', 'b', 'c', 'c',
#         'd', 'd', 'a', 'b', 'a', 'b', 'c', 'c', 'd', 'd', 'a', 'b'],
#        dtype=object))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=3)
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (48, 16, 48, 16)

# %%
scaler = StandardScaler()

# Fit on training set only.
scaler.fit(X_train)

# Apply transform to both the training set and the test set.
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
clf = LogisticRegression()

# %%
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ### Letters: Predicted vs. Actual

# %%
df_predictions = DataFrame(
    [(clf.predict(X_test[i].reshape(1,-1))[0],
    y_test[i]) for i in range(len(y_test))],
    columns = ["Predicted", "Actual"])
df_predictions
# Out:
#    Predicted Actual
# 0          a      a
# 1          b      b
# 2          c      c
# 3          d      d
# 4          a      a
# 5          a      b
# 6          b      b
# 7          c      c
# 8          b      b
# 9          d      d
# 10         d      d
# 11         d      d
# 12         c      c
# 13         a      a
# 14         d      d
# 15         d      d

# %% [markdown]
# ### Probabilities of each letter, by row:

# %%
#for i in range(len(X_test)):
#    print('probability', clf.predict_proba(X_test[i].reshape(1,-1)))
print(clf.predict_proba(X_test[i].reshape(1,-1))[0])
df_probabilities = DataFrame(([clf.predict_proba(X_test[i].reshape(1,-1))[0]]) \
                              for i in range(len(y_test)))
df_probabilities
# Out:
# [9.50097182e-05 2.30290200e-05 1.71053640e-05 9.99864856e-01]
#                                                     0
# 0   [0.9994643444199989, 0.00021395262127211597, 0...
# 1   [2.246843476868879e-06, 0.9999977438560985, 3....
# 2   [0.0037628277965812986, 0.001235457317210302, ...
# 3   [0.0064246433567102254, 0.003965315598702221, ...
# 4   [0.9989137675147958, 0.00010296035836202457, 6...
# 5   [0.6347712342116019, 0.3650226263623535, 0.000...
# 6   [1.5477366593949592e-08, 0.9999998452299277, 2...
# 7   [0.005604438642803807, 0.010001722910790602, 0...
# 8   [0.04069773950154049, 0.6562872698474681, 0.23...
# 9   [0.00968669569612288, 0.0013202210583224323, 0...
# 10  [0.06401716884827799, 0.006964729264606582, 0....
# 11  [0.051358050196900235, 0.006382614204574685, 0...
# 12  [0.2997081394616096, 0.08183902905683696, 0.56...
# 13  [0.999999956950194, 3.944008151572556e-08, 4.7...
# 14  [0.022052699716201333, 0.0013210629798959526, ...
# ...
