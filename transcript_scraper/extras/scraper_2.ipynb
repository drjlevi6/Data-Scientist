# %% [markdown]
# # transcript-scraper:
#
# Get text of LinkedIn Learning courses' transcripts

# %%
import requests
from bs4 import BeautifulSoup

# %%
sample_url = 'https://www.linkedin.com/learning/' + \
'python-for-data-science-essential-training-part-1/data-parsing'

# %%
results = requests.get(sample_url)
soup = BeautifulSoup(results.text, "html.parser")
transcript_div = soup.find("div", attrs={'class': 'transcripts__copy'})
s = list(transcript_div.stripped_strings)[1]
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="d_learning_course_video_guest" name="pageKey"/>
# <meta content="locked_video" name="linkedin:pageTag"/>
# <meta content="en_US" name="locale"/>
# <meta data-app-version="2.0.1755" data-browser-id="6606f753-af18-4565-8854-0938e2f10ee4" data-call-tree-id="AAYODTYmUQ0m0T1BxUEZTA==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="learning-guest-frontend" data-page-instance="urn:li:page:learning_course_video_guest;66ljyIIWQTm2V2RYx2sSUA==" data-service-name="learning-guest-frontend" id="config"/>
# <link href="https://www.linkedin.com/learning/python-for-data-science-essential-training-part-1/data-parsing" rel="canonical"/>
# <!-- --><!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <script>
#           function getDfd() {let yFn,nFn;const p=new Promise(function(y, n){yFn=y;nFn=n;});p.resolve=yFn;p.reject=nFn;return p;}
# ...

# %%
#import re
#re.sub(' +', ' ', s)
